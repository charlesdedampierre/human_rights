# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['font.size'] = 11

# %%
# Load data and check coverage
conn = sqlite3.connect('../output/literary_works.db')

# Coverage statistics
total_items = pd.read_sql('SELECT COUNT(DISTINCT item_id) as cnt FROM literary_works', conn)['cnt'].values[0]
items_with_year = pd.read_sql('SELECT COUNT(DISTINCT item_id) as cnt FROM literary_works WHERE year IS NOT NULL', conn)['cnt'].values[0]
items_with_region = pd.read_sql('''
    SELECT COUNT(DISTINCT lw.item_id) as cnt 
    FROM literary_works lw
    LEFT JOIN countries c ON lw.modern_country = c.modern_country
    WHERE c.macro_region IS NOT NULL
''', conn)['cnt'].values[0]
items_with_both = pd.read_sql('''
    SELECT COUNT(DISTINCT lw.item_id) as cnt 
    FROM literary_works lw
    LEFT JOIN countries c ON lw.modern_country = c.modern_country
    WHERE lw.year IS NOT NULL AND c.macro_region IS NOT NULL
''', conn)['cnt'].values[0]

print("=" * 50)
print("DATA COVERAGE")
print("=" * 50)
print(f"Total unique items in database: {total_items:,}")
print(f"Items with year:                {items_with_year:,} ({items_with_year/total_items*100:.1f}%)")
print(f"Items with region:              {items_with_region:,} ({items_with_region/total_items*100:.1f}%)")
print(f"Items with BOTH year AND region: {items_with_both:,} ({items_with_both/total_items*100:.1f}%)")
print("=" * 50)

# Query with deduplication: one row per unique item_id
# For works with multiple years, we keep the earliest year (MIN)
# For works with multiple regions, we keep all (but deduplicate per item_id + region)
query = """
WITH deduplicated AS (
    SELECT 
        lw.item_id,
        lw.itemLabel,
        lw.instanceLabel,
        lw.countryLabel,
        lw.languageLabel,
        lw.authorLabel,
        MIN(lw.year) as year,
        c.macro_region,
        c.region
    FROM literary_works lw
    LEFT JOIN countries c ON lw.modern_country = c.modern_country
    LEFT JOIN instances i ON lw.instanceLabel = i.label
    WHERE lw.year IS NOT NULL 
      AND lw.year < 1900
      AND (i.excluded = 0 OR i.excluded IS NULL)
    GROUP BY lw.item_id, c.macro_region, c.region
)
SELECT * FROM deduplicated
WHERE macro_region IS NOT NULL
"""

df = pd.read_sql(query, conn)
conn.close()

print(f"\nAnalysis subset (year < 1900, non-excluded types):")
print(f"Total unique literary works: {df['item_id'].nunique():,} ({df['item_id'].nunique()/total_items*100:.1f}% of all items)")
print(f"Date range: {df['year'].min()} - {df['year'].max()}")
print(f"Unique macro regions: {df['macro_region'].nunique()}")
print(f"Unique regions: {df['region'].nunique()}")
print(f"Unique instance types: {df['instanceLabel'].nunique()}")
# Out:
# ==================================================
# DATA COVERAGE
# ==================================================
# Total unique items in database: 1,347,347
# Items with year:                362,033 (26.9%)
# Items with region:              708,538 (52.6%)
# Items with BOTH year AND region: 265,875 (19.7%)
# ==================================================
#
# Analysis subset (year < 1900, non-excluded types):
# Total unique literary works: 41,568 (3.1% of all items)
# Date range: -2999 - 1899
# Unique macro regions: 9
# Unique regions: 26
# Unique instance types: 546

# %%
# Overview: Works by macro region (counting unique item_ids per macro region)
macro_region_counts = df.groupby('macro_region')['item_id'].nunique().sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 5))
colors = sns.color_palette('Blues_r', len(macro_region_counts))
bars = ax.barh(macro_region_counts.index[::-1], macro_region_counts.values[::-1], color=colors[::-1])
ax.set_xlabel('Number of Works')
ax.set_title('Literary Works by Macro Region (before 1900)', fontsize=14, fontweight='bold')
for bar, val in zip(bars, macro_region_counts.values[::-1]):
    ax.text(val + macro_region_counts.max()*0.01, bar.get_y() + bar.get_height()/2, 
            f'{val:,}', va='center', fontsize=9)
ax.set_xlim(0, macro_region_counts.max() * 1.15)
plt.tight_layout()
plt.show()

# %%
# Overview: Works by detailed region (counting unique item_ids per region)
region_counts = df.groupby('region')['item_id'].nunique().sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(12, 10))
colors = sns.color_palette('Greens_r', len(region_counts))
bars = ax.barh(region_counts.index[::-1], region_counts.values[::-1], color=colors[::-1])
ax.set_xlabel('Number of Works')
ax.set_title('Literary Works by Region (before 1900)', fontsize=14, fontweight='bold')
for bar, val in zip(bars, region_counts.values[::-1]):
    ax.text(val + region_counts.max()*0.01, bar.get_y() + bar.get_height()/2, 
            f'{val:,}', va='center', fontsize=8)
ax.set_xlim(0, region_counts.max() * 1.15)
plt.tight_layout()
plt.show()

# %%
# Timeline: Works count per 100-year periods (log scale, counting unique item_ids)
df['century'] = (df['year'] // 100) * 100

counts_100y = df.groupby('century')['item_id'].nunique()

fig, ax = plt.subplots(figsize=(14, 6))
ax.bar(counts_100y.index, counts_100y.values, width=80, color='steelblue', edgecolor='white')
ax.set_xlabel('Year')
ax.set_ylabel('Number of Works (log scale)')
ax.set_title('Literary Works per 100-Year Period (before 1900)', fontsize=14, fontweight='bold')
ax.set_yscale('log')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x), ',')))

min_year = (counts_100y.index.min() // 100) * 100
max_year = (counts_100y.index.max() // 100 + 1) * 100
ax.set_xticks(range(min_year, max_year + 1, 200))
ax.set_xticklabels([str(y) for y in range(min_year, max_year + 1, 200)], rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
# Normalized stacked bar chart: Distribution per macro region over time (counting unique item_ids)
df['century'] = (df['year'] // 100) * 100
top_macro_regions = df.groupby('macro_region')['item_id'].nunique().sort_values(ascending=False).head(6).index.tolist()

timeline = df[df['macro_region'].isin(top_macro_regions)].groupby(['century', 'macro_region'])['item_id'].nunique().unstack(fill_value=0)
timeline = timeline[top_macro_regions]

# Normalize by century (each century = 100%)
timeline_norm = timeline.div(timeline.sum(axis=1), axis=0) * 100

fig, ax = plt.subplots(figsize=(14, 6))
timeline_norm.plot(kind='bar', stacked=True, ax=ax, colormap='tab10', width=0.8)
ax.set_xlabel('Century')
ax.set_ylabel('Percentage of Works')
ax.set_title('Macro Regional Distribution of Literary Works Over Time (Normalized)', fontsize=14, fontweight='bold')
ax.legend(title='Macro Region', bbox_to_anchor=(1.02, 1), loc='upper left')
ax.set_xticklabels([f'{int(x)}' for x in timeline_norm.index], rotation=45, ha='right')
ax.set_ylim(0, 100)
plt.tight_layout()
plt.show()

# %%
# Co-occurring Instance Types (excluding 'literary work')
# Find which work types tend to appear together on the same works
from itertools import combinations
from collections import Counter

conn = sqlite3.connect('../output/literary_works.db')

# Get all instance types per item (excluding 'literary work' as it's ubiquitous)
query_cooccur = """
SELECT DISTINCT lw.item_id, lw.instanceLabel
FROM literary_works lw
LEFT JOIN countries c ON lw.modern_country = c.modern_country
LEFT JOIN instances i ON lw.instanceLabel = i.label
WHERE lw.year IS NOT NULL 
  AND lw.year < 1900
  AND c.macro_region IS NOT NULL
  AND (i.excluded = 0 OR i.excluded IS NULL)
  AND lw.instanceLabel != 'literary work'
"""

df_cooccur = pd.read_sql(query_cooccur, conn)
conn.close()

# Group by item_id to get all instance types per work
items_instances = df_cooccur.groupby('item_id')['instanceLabel'].apply(set).reset_index()

# Filter to items with multiple instance types
multi_instance = items_instances[items_instances['instanceLabel'].apply(len) > 1]

# Count co-occurrences
cooccurrence = Counter()
for instances in multi_instance['instanceLabel']:
    for pair in combinations(sorted(instances), 2):
        cooccurrence[pair] += 1

# Create DataFrame of top co-occurring pairs
cooccur_df = pd.DataFrame([
    {'Instance Type 1': a, 'Instance Type 2': b, 'Co-occurrences': count}
    for (a, b), count in cooccurrence.most_common(25)
])
cooccur_df.index = range(1, len(cooccur_df) + 1)
cooccur_df.index.name = '#'

print(f"Items with multiple instance types (excl. 'literary work'): {len(multi_instance):,}")
print(f"\nTop 25 Co-occurring Instance Type Pairs:")
print(cooccur_df.to_string())
# Out:
# Items with multiple instance types (excl. 'literary work'): 3,979
#
# Top 25 Co-occurring Instance Type Pairs:
#              Instance Type 1                  Instance Type 2  Co-occurrences
# #
# 1               book edition                   penny dreadful             649
# 2                       book               serialized fiction             554
# 3                     lyrics                  translated song             372
# 4           translation work  version, edition or translation             256
# 5                    chapter               serialized fiction             207
# 6        lyrico-musical work         musical work/composition              92
# 7         serialized fiction                 translation work              80
# 8     collection of articles         series of creative works              69
# 9                   treatise                     written work              69
# 10            penny dreadful                          reprint              55
# 11                      song  version, edition or translation              54
# 12                     fable  version, edition or translation              51
# 13                   article                     news article              39
# 14           translated work                         treatise              37
# 15                 incunable  version, edition or translation              36
# 16          translation work                         treatise              34
# 17  musical work/composition                    nursery rhyme              33
# 18                fairy tale  version, edition or translation              32
# 19            reference work                  translated work              32
# 20              news article                         obituary              31
# 21    dramatico-musical work         musical work/composition              29
# 22                   chapter                 translation work              29
# 23                   Märchen                          chapter              28
# 24                 monograph                           volume              27
# 25           translated work                     written work              25

# %%
# Distribution of Work Types by Time Period
# Define time periods
periods = [
    ('Before 0', df['year'] < 0),
    ('0 - 1500', (df['year'] >= 0) & (df['year'] < 1500)),
    ('1500 - 1800', (df['year'] >= 1500) & (df['year'] < 1800)),
    ('1800 - 1900', (df['year'] >= 1800) & (df['year'] < 1900))
]

fig, axes = plt.subplots(2, 2, figsize=(14, 12))
axes = axes.flatten()

for idx, (period_name, mask) in enumerate(periods):
    ax = axes[idx]
    period_df = df[mask]
    
    # Get top 10 work types for this period
    instance_counts = period_df.groupby('instanceLabel')['item_id'].nunique().sort_values(ascending=False).head(10)
    
    colors = sns.color_palette('Greens_r', len(instance_counts))
    bars = ax.barh(instance_counts.index[::-1], instance_counts.values[::-1], color=colors[::-1])
    ax.set_xlabel('Number of Works')
    ax.set_title(f'{period_name} (n={period_df["item_id"].nunique():,})', fontsize=12, fontweight='bold')
    
    for bar, val in zip(bars, instance_counts.values[::-1]):
        ax.text(val + instance_counts.max()*0.02, bar.get_y() + bar.get_height()/2, 
                f'{val:,}', va='center', fontsize=8)
    ax.set_xlim(0, instance_counts.max() * 1.2)

plt.suptitle('Top 10 Work Types by Time Period', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Examples Section - Most famous work for each of the top 50 work types (by sitelinks)
conn = sqlite3.connect('../output/literary_works.db')

# Get data with sitelink_count and region
query_examples = """
SELECT DISTINCT
    lw.item_id,
    lw.itemLabel,
    lw.instanceLabel,
    lw.authorLabel,
    lw.sitelink_count,
    c.macro_region,
    c.region,
    MIN(lw.year) as year
FROM literary_works lw
LEFT JOIN countries c ON lw.modern_country = c.modern_country
LEFT JOIN instances i ON lw.instanceLabel = i.label
WHERE lw.year IS NOT NULL 
  AND lw.year < 1900
  AND c.macro_region IS NOT NULL
  AND (i.excluded = 0 OR i.excluded IS NULL)
GROUP BY lw.item_id, c.macro_region, c.region
"""

df_examples = pd.read_sql(query_examples, conn)

# Get English Wikipedia URLs
en_wiki = pd.read_sql("""
    SELECT item_id, sitelink as en_wikipedia 
    FROM sitelinks 
    WHERE sitelink LIKE '%en.wikipedia.org%'
""", conn)
conn.close()

# Merge with English Wikipedia URLs
df_examples = df_examples.merge(en_wiki, on='item_id', how='left')

def get_top_examples(data, top_n=50):
    """Get most famous work for each of the top N work types."""
    top_types = data.groupby('instanceLabel')['item_id'].nunique().sort_values(ascending=False).head(top_n).index.tolist()
    
    examples = []
    for instance_type in top_types:
        type_df = data[data['instanceLabel'] == instance_type]
        if len(type_df) > 0:
            most_famous = type_df.loc[type_df['sitelink_count'].idxmax()]
            # Use English Wikipedia if available, otherwise Wikidata
            if pd.notna(most_famous.get('en_wikipedia')):
                url = most_famous['en_wikipedia']
            else:
                url = f"https://www.wikidata.org/wiki/{most_famous['item_id']}"
            examples.append({
                'Work Type': instance_type,
                'Count': type_df['item_id'].nunique(),
                'Most Famous Work': most_famous['itemLabel'],
                'Author': most_famous['authorLabel'] if pd.notna(most_famous['authorLabel']) else '-',
                'Year': int(most_famous['year']) if pd.notna(most_famous['year']) else '-',
                'Sitelinks': int(most_famous['sitelink_count']) if pd.notna(most_famous['sitelink_count']) else 0,
                'Wikipedia': url
            })
    
    result = pd.DataFrame(examples)
    result.index = range(1, len(result) + 1)
    result.index.name = '#'
    return result

# Western Europe DataFrame
df_west = df_examples[df_examples['macro_region'] == 'Western Europe']
examples_west_df = get_top_examples(df_west, 50)

# Non-Western Europe DataFrame
df_non_west = df_examples[df_examples['macro_region'] != 'Western Europe']
examples_non_west_df = get_top_examples(df_non_west, 50)

# %%
# Western Europe - Top 50 Work Types with Most Famous Example
examples_west_df
# Out:
#                           Work Type  Count  \
# #
# 1                     literary work  21420
# 2            collection of articles   1197
# 3            dramatico-musical work    998
# 4                    penny dreadful    951
# 5                     public notice    681
# 6                serialized fiction    680
# 7                    Christian hymn    592
# 8                         epic poem    589
# 9                         incunable    583
# 10                             book    437
# 11               genealogical table    357
# 12                           lyrics    303
# 13  version, edition or translation    301
# 14                         treatise    234
# 15                 translation work    224
# 16                     book edition    212
# 17                  translated work    130
# 18                        biography    118
# 19                    dramatic work    117
# 20                       fairy tale    112
# 21                          chapter    111
# 22                         yearbook    109
# 23                       periodical    106
# 24         musical work/composition    104
# 25                       dictionary     87
# 26                     written work     82
# 27                  translated song     74
# 28          biographical dictionary     73
# 29              lyrico-musical work     70
# 30               philosophical work     67
# 31                poetry collection     67
# 32            scientific literature     63
# 33              literary fairy tale     62
# 34                  scientific book     55
# 35                   reference work     50
# 36                       papal bull     46
# 37                        monograph     45
# 38                          reprint     42
# 39                  medical journal     40
# 40                             song     40
# 41                     novelization     39
# 42                        chronicle     36
# 43                    annual report     35
# 44                          Märchen     34
# 45                          preface     33
# 46                           volume     33
# 47                          article     33
# 48                         obituary     32
# 49                      book review     31
# 50                 non-fiction work     28
#
#                                      Most Famous Work  \
# #
# 1                                         Don Quixote
# 2                 Le Brésil et la Société brésilienne
# 3                                              Carmen
# 4                                  Varney the Vampire
# 5                                           Q19135890
# 6                                    The Time Machine
# 7                                  How Great Thou Art
# 8                                         Pan Tadeusz
# 9                                       36-line Bible
# 10                                         Q101003189
# 11  Stammtafel der Ritter Wörtz von Sprengenstein ...
# 12                             O Come All Ye Faithful
# 13                                    Sixtine Vulgate
# 14                         De humani corporis fabrica
# 15             Legend of the Purgatory of St. Patrick
# 16             Cousin Cecil; or, The Wheel of fortune
# 17                                   Hortus sanitatis
# 18                                          Q10697050
# 19                                             Hamlet
# 20                                         la Mermaid
# 21                                           Mestermø
# 22                                             Metate
# 23                                  Journal asiatique
# 24                                    Deutschlandlied
# 25                Dictionnaire de la langue française
# 26                     Allgemeine Deutsche Biographie
# 27                         All glory, laud and honour
# 28                      Prosopographia Imperii Romani
# 29                                Die schöne Müllerin
# 30                            Critique of Pure Reason
# 31                             The Passionate Pilgrim
# 32                                           Zoonomia
# 33                                     The Snow Queen
# 34                        Spicilegium Florae Lipsicae
# 35                                   Summa Theologica
# 36                                     Exsurge Domine
# 37  A Philosophical Enquiry into the Origin of Our...
# 38  Arwed Gillenstern. A Swedish Historical Tale o...
# 39                                         The Lancet
# 40                                Det er hvidt herude
# 41                                  The Wife's Secret
# 42                                 Annales Bertiniani
# 43                Auckland Museum Annual Report, 1868
# 44      Kværnen, som staaer og maler paa Havsens Bund
# 45                                 Alice de Chambrier
# 46              Arabian Nights Entertainments, Vol. 1
# 47  Entdeckungsfahrten des deutschen Dampfers „Samoa“
# 48               Henry K. Lattin (1806-1894) obituary
# 49          Junqueira Freire: Inspirações do Claustro
# 50                                   Den danske Atlas
#
#                                        Author  Year  Sitelinks  \
# #
# 1                         Miguel de Cervantes  1605        146
# 2                            Adolphe d’Assier  1863          2
# 3                               Georges Bizet  1875         74
# 4                         James Malcolm Rymer  1845         11
# 5                                           -  1891          1
# 6                                 H. G. Wells  1895         57
# 7                                           -  1885         20
# 8                             Adam Mickiewicz  1834         34
# 9                                           -  1500          6
# 10                       Isaac Abraham Euchel  1786          0
# 11                                          -  1889          1
# 12                                          -  1852          1
# 13                                          -  1590          9
# 14                           Andreas Vesalius  1543         27
# 15                           Henry of Saltrey  1200          4
# 16                        James Malcolm Rymer  1852          1
# 17                                          -  1491         14
# 18                         Erik Gustaf Geijer  1820          1
# 19                        William Shakespeare  1813        139
# 20                    Hans Christian Andersen  1837         78
# 21                                 Jørgen Moe  1852          7
# 22                                          -  1894          1
# 23                                          -  1822         14
# 24  August Heinrich Hoffmann von Fallersleben  1841         97
# 25                               Émile Littré  1841         13
# 26                            various authors  1875         29
# 27                        Theodulf of Orléans  1861          4
# 28                                          -  1897          7
# 29                             Wilhelm Müller  1823         28
# 30                              Immanuel Kant  1781         57
# 31                        William Shakespeare  1599         16
# 32                             Erasmus Darwin  1794         10
# 33                    Hans Christian Andersen  1844         60
# 34       Johann Christian Daniel von Schreber  1771          3
# 35                             Thomas Aquinas  1274         38
# 36                                      Leo X  1520         22
# 37                               Edmund Burke  1757         15
# 38                                          -  1823          0
# 39                                          -  1823         50
# 40                                          -  1838          2
# 41                      George William Lovell  1846          1
# 42                                          -   850         27
# 43              Auckland Institute and Museum  1869          1
# 44                                 Jørgen Moe  1852          8
# 45                             Philippe Godet  1886          1
# 46                            Antoine Galland  1706          2
# 47              Friedrich Hermann Otto Finsch  1886          2
# 48                                          -  1894          1
# 49                                          -  1866          1
# 50                                          -  1763          3
#
#                                             Wikipedia
# #
# 1           https://en.wikipedia.org/wiki/Don_Quixote
# 2             https://www.wikidata.org/wiki/Q17363084
# 3                https://en.wikipedia.org/wiki/Carmen
# 4    https://en.wikipedia.org/wiki/Varney_the_Vampire
# 5             https://www.wikidata.org/wiki/Q19135890
# 6      https://en.wikipedia.org/wiki/The_Time_Machine
# 7    https://en.wikipedia.org/wiki/How_Great_Thou_Art
# 8           https://en.wikipedia.org/wiki/Pan_Tadeusz
# 9         https://en.wikipedia.org/wiki/36-line_Bible
# 10           https://www.wikidata.org/wiki/Q101003189
# 11            https://www.wikidata.org/wiki/Q16055253
# 12            https://www.wikidata.org/wiki/Q30041440
# 13      https://en.wikipedia.org/wiki/Sixtine_Vulgate
# 14  https://en.wikipedia.org/wiki/De_Humani_Corpor...
# 15  https://en.wikipedia.org/wiki/Legend_of_the_Pu...
# 16           https://www.wikidata.org/wiki/Q110008802
# 17     https://en.wikipedia.org/wiki/Hortus_Sanitatis
# 18            https://www.wikidata.org/wiki/Q10697050
# 19               https://en.wikipedia.org/wiki/Hamlet
# 20   https://en.wikipedia.org/wiki/The_Little_Mermaid
# 21      https://en.wikipedia.org/wiki/The_Master_Maid
# 22    https://en.wikipedia.org/wiki/Metate_(yearbook)
# 23    https://en.wikipedia.org/wiki/Journal_asiatique
# 24      https://en.wikipedia.org/wiki/Deutschlandlied
# 25  https://en.wikipedia.org/wiki/Dictionnaire_de_...
# 26  https://en.wikipedia.org/wiki/Allgemeine_Deuts...
# 27  https://en.wikipedia.org/wiki/All_Glory,_Laud_...
# 28  https://en.wikipedia.org/wiki/Prosopographia_I...
# 29  https://en.wikipedia.org/wiki/Die_sch%C3%B6ne_...
# 30  https://en.wikipedia.org/wiki/Critique_of_Pure...
# 31  https://en.wikipedia.org/wiki/The_Passionate_P...
# 32             https://en.wikipedia.org/wiki/Zoonomia
# 33       https://en.wikipedia.org/wiki/The_Snow_Queen
# 34            https://www.wikidata.org/wiki/Q13554413
# 35     https://en.wikipedia.org/wiki/Summa_Theologica
# 36       https://en.wikipedia.org/wiki/Exsurge_Domine
# 37  https://en.wikipedia.org/wiki/A_Philosophical_...
# 38           https://www.wikidata.org/wiki/Q110008193
# 39           https://en.wikipedia.org/wiki/The_Lancet
# 40            https://www.wikidata.org/wiki/Q12308431
# 41  https://en.wikipedia.org/wiki/The_Wife%27s_Secret
# 42   https://en.wikipedia.org/wiki/Annales_Bertiniani
# 43           https://www.wikidata.org/wiki/Q131690453
# 44  https://en.wikipedia.org/wiki/Why_the_Sea_is_Salt
# 45            https://www.wikidata.org/wiki/Q19131666
# 46           https://www.wikidata.org/wiki/Q130396496
# 47           https://www.wikidata.org/wiki/Q115697665
# 48           https://www.wikidata.org/wiki/Q104533883
# 49            https://www.wikidata.org/wiki/Q19556531
# 50            https://www.wikidata.org/wiki/Q11965136

# %%
# Non-Western Europe - Top 50 Work Types with Most Famous Example
examples_non_west_df
# Out:
#                              Work Type  Count  \
# #
# 1                        literary work   6638
# 2      version, edition or translation    282
# 3                     translation work    264
# 4               dramatico-musical work    159
# 5                                  ode     46
# 6                        public notice     39
# 7                           periodical     39
# 8                           dictionary     35
# 9                       religious text     33
# 10                    narrative poetry     32
# 11                       dramatic work     31
# 12                          humoresque     30
# 13                          manuscript     30
# 14                     medical journal     29
# 15                          fairy tale     27
# 16                       Buddhist text     26
# 17                             article     23
# 18                        written work     23
# 19                           chronicle     21
# 20                            document     21
# 21                         short novel     21
# 22                            treatise     20
# 23                           incunable     17
# 24                             oration     17
# 25                          adaptation     17
# 26                           epic poem     17
# 27         historical non-fiction work     16
# 28                     national anthem     15
# 29                        news article     13
# 30            musical work/composition     12
# 31                     society journal     12
# 32                                song     12
# 33                         travel book     11
# 34             encyclopedic dictionary     10
# 35                      literary cycle     10
# 36                   literary fragment      9
# 37                               diary      8
# 38                bilingual dictionary      8
# 39                            yearbook      8
# 40                        history book      8
# 41  dictionary of the Russian language      8
# 42                           biography      7
# 43             biographical dictionary      7
# 44                               fable      7
# 45                     school yearbook      7
# 46                    series of prints      7
# 47                      cycle of poems      7
# 48             New Testament apocrypha      7
# 49                                hymn      6
# 50              explanatory dictionary      6
#
#                                      Most Famous Work  \
# #
# 1                                              Qur’an
# 2                             Three Character Classic
# 3                                        Oliwer Twist
# 4                                       Eugene Onegin
# 5                                       Olympic Ode I
# 6                                          Q126877452
# 7                                             Science
# 8                             Dīwān ul-Lughat al-Turk
# 9                                      Book of Mormon
# 10                       The Fountain of Bakhchisaray
# 11                                           Antigone
# 12                               The Lawyer's Romance
# 13                                   Gospel of Philip
# 14    The Journal of the American Medical Association
# 15                                       Father Frost
# 16                           Memoirs of Eminent Monks
# 17                                          Q16055980
# 18                                      Diamond Sutra
# 19                           Novgorod First Chronicle
# 20  Surinaamsche Staatkundige Almanak voor den Jaa...
# 21                           The Death of Ivan Ilyich
# 22                                          Huainanzi
# 23                        Missale Romanum Glagolitice
# 24                                       On the Crown
# 25                          The Dragonfly and the Ant
# 26                                      Epic of Manas
# 27                                        Nihon Shoki
# 28                                           Kimigayo
# 29                                          Q19524079
# 30                           The Star-Spangled Banner
# 31      Bulletin of the American Mathematical Society
# 32                                 Danielis prophetia
# 33                       Seyahatname of Evliya Çelebi
# 34                             Encyclopedia Americana
# 35        The Tales of the Late Ivan Petrovich Belkin
# 36                        Rylands Library Papyrus P52
# 37                                          Kakumeiki
# 38                                        Nippo Jisho
# 39                                      The Lucky Bag
# 40                     Records of the Grand Historian
# 41                  Dictionary of the Russian Academy
# 42                                          Q11492231
# 43  Great Tang Biographies of Eminent Monks Who So...
# 44                     Golden Apple and Nine Peacocks
# 45                                          The Makio
# 46                                      Ukiyo Tsuzuki
# 47                            Sonnets from the Crimea
# 48                                      Acts of Peter
# 49                                   Hanuman Chalisha
# 50                      Full Church Slavic dictionary
#
#                          Author  Year  Sitelinks  \
# #
# 1                             -   631        280
# 2              Stanislas Julien  1300         28
# 3               Charles Dickens  1845          2
# 4                             -  1877         45
# 5                        Pindar  -475          2
# 6                             -  1858          0
# 7                             -  1880         62
# 8            Mahmud al-Kashgari  1266         27
# 9                  Joseph Smith  1830        124
# 10            Alexander Pushkin  1821         26
# 11                    Sophocles  -441         69
# 12                Anton Chekhov  1883          2
# 13                            -   300         40
# 14                            -  1883         27
# 15                     folklore  1860          9
# 16                      Huijiao   530         13
# 17         Karel Ladislav Kukla  1893          1
# 18                            -   868         52
# 19                            -  1016         22
# 20                            -  1817          0
# 21                  Leo Tolstoy  1882         37
# 22                       Liu An  -200         28
# 23                            -  1483         10
# 24                  Demosthenes  -350         13
# 25                  Ivan Krylov  1808          7
# 26                            -  1885         50
# 27                Ō no Yasumaro   720         60
# 28                            -  1880         96
# 29                 Josef Štolba  1887          1
# 30                            -  1814        106
# 31                            -  1891         11
# 32                            -  1420          2
# 33                Evliya Çelebi  1630         19
# 34               Francis Lieber  1829         33
# 35            Alexander Pushkin  1830         22
# 36                            -   125         28
# 37                       Shōshō  1700          1
# 38             Society of Jesus  1603         13
# 39  United States Naval Academy  1894          2
# 40                    Sima Qian   -89         59
# 41                            -  1789          3
# 42                            -   900          1
# 43                       Yijing   691          3
# 44                            -  1853          7
# 45                            -  1880          1
# 46                            -  1684          1
# 47              Adam Mickiewicz  1826          9
# 48                            -   200         22
# 49                     Tulsidas  1600         25
# 50            Grigory Dyachenko  1899          3
#
#                                             Wikipedia
# #
# 1                 https://en.wikipedia.org/wiki/Quran
# 2   https://en.wikipedia.org/wiki/Three_Character_...
# 3             https://www.wikidata.org/wiki/Q32837053
# 4   https://en.wikipedia.org/wiki/Eugene_Onegin_(o...
# 5            https://en.wikipedia.org/wiki/Olympian_1
# 6            https://www.wikidata.org/wiki/Q126877452
# 7     https://en.wikipedia.org/wiki/Science_(journal)
# 8   https://en.wikipedia.org/wiki/D%C4%ABw%C4%81n_...
# 9        https://en.wikipedia.org/wiki/Book_of_Mormon
# 10  https://en.wikipedia.org/wiki/The_Fountain_of_...
# 11  https://en.wikipedia.org/wiki/Antigone_(Sophoc...
# 12             https://www.wikidata.org/wiki/Q3226615
# 13     https://en.wikipedia.org/wiki/Gospel_of_Philip
# 14                 https://en.wikipedia.org/wiki/JAMA
# 15  https://en.wikipedia.org/wiki/Father_Frost_(fa...
# 16  https://en.wikipedia.org/wiki/Memoirs_of_Emine...
# 17            https://www.wikidata.org/wiki/Q16055980
# 18        https://en.wikipedia.org/wiki/Diamond_Sutra
# 19  https://en.wikipedia.org/wiki/Novgorod_First_C...
# 20           https://www.wikidata.org/wiki/Q124821404
# 21  https://en.wikipedia.org/wiki/The_Death_of_Iva...
# 22            https://en.wikipedia.org/wiki/Huainanzi
# 23  https://en.wikipedia.org/wiki/Missale_Romanum_...
# 24         https://en.wikipedia.org/wiki/On_the_Crown
# 25            https://www.wikidata.org/wiki/Q52724189
# 26        https://en.wikipedia.org/wiki/Epic_of_Manas
# 27          https://en.wikipedia.org/wiki/Nihon_Shoki
# 28             https://en.wikipedia.org/wiki/Kimigayo
# 29            https://www.wikidata.org/wiki/Q19524079
# 30  https://en.wikipedia.org/wiki/The_Star-Spangle...
# 31  https://en.wikipedia.org/wiki/Bulletin_of_the_...
# 32           https://www.wikidata.org/wiki/Q137460513
# 33     https://en.wikipedia.org/wiki/Seyahatn%C3%A2me
# 34  https://en.wikipedia.org/wiki/Encyclopedia_Ame...
# 35     https://en.wikipedia.org/wiki/The_Belkin_Tales
# 36  https://en.wikipedia.org/wiki/Rylands_Library_...
# 37            https://www.wikidata.org/wiki/Q11658955
# 38          https://en.wikipedia.org/wiki/Nippo_Jisho
# 39            https://en.wikipedia.org/wiki/Lucky_Bag
# 40                https://en.wikipedia.org/wiki/Shiji
# 41             https://www.wikidata.org/wiki/Q4423783
# 42            https://www.wikidata.org/wiki/Q11492231
# 43            https://www.wikidata.org/wiki/Q10934295
# 44  https://en.wikipedia.org/wiki/The_Nine_Peahens...
# 45           https://www.wikidata.org/wiki/Q124420078
# 46           https://www.wikidata.org/wiki/Q122962174
# 47  https://en.wikipedia.org/wiki/The_Crimean_Sonnets
# 48        https://en.wikipedia.org/wiki/Acts_of_Peter
# 49      https://en.wikipedia.org/wiki/Hanuman_Chalisa
# 50            https://www.wikidata.org/wiki/Q30520428

# %%
# =============================================================================
# WORKS CONTENT - Wikisource Availability by Time Period
# =============================================================================

conn = sqlite3.connect('../output/literary_works.db')

# Get all works with year and check for Wikisource links
query_wikisource = """
WITH works_with_year AS (
    SELECT 
        lw.item_id,
        MIN(lw.year) as year
    FROM literary_works lw
    LEFT JOIN countries c ON lw.modern_country = c.modern_country
    LEFT JOIN instances i ON lw.instanceLabel = i.label
    WHERE lw.year IS NOT NULL 
      AND lw.year < 1900
      AND c.macro_region IS NOT NULL
      AND (i.excluded = 0 OR i.excluded IS NULL)
    GROUP BY lw.item_id
),
wikisource_items AS (
    SELECT DISTINCT item_id
    FROM sitelinks
    WHERE sitelink LIKE '%wikisource%'
)
SELECT 
    w.item_id,
    w.year,
    CASE WHEN ws.item_id IS NOT NULL THEN 1 ELSE 0 END as has_wikisource
FROM works_with_year w
LEFT JOIN wikisource_items ws ON w.item_id = ws.item_id
"""

df_ws = pd.read_sql(query_wikisource, conn)
conn.close()

# Define time periods
def assign_period(year):
    if year < 0:
        return 'Before 0'
    elif year < 1500:
        return '0 - 1500'
    elif year < 1800:
        return '1500 - 1800'
    else:
        return '1800 - 1900'

df_ws['period'] = df_ws['year'].apply(assign_period)

# Calculate statistics per period
period_order = ['Before 0', '0 - 1500', '1500 - 1800', '1800 - 1900']
stats = []
for period in period_order:
    period_df = df_ws[df_ws['period'] == period]
    total = len(period_df)
    with_ws = period_df['has_wikisource'].sum()
    pct = (with_ws / total * 100) if total > 0 else 0
    stats.append({
        'Time Period': period,
        'Total Works': total,
        'With Wikisource': int(with_ws),
        'Percentage': f'{pct:.1f}%'
    })

# Add total row
total_works = len(df_ws)
total_ws = df_ws['has_wikisource'].sum()
total_pct = (total_ws / total_works * 100) if total_works > 0 else 0
stats.append({
    'Time Period': 'TOTAL',
    'Total Works': total_works,
    'With Wikisource': int(total_ws),
    'Percentage': f'{total_pct:.1f}%'
})

stats_df = pd.DataFrame(stats)
stats_df.index = [''] * len(stats_df)

print("=" * 60)
print("WORKS CONTENT - Wikisource Availability")
print("=" * 60)
print("\nLiterary works with Wikisource links (full text available):\n")
print(stats_df.to_string(index=False))
print("\n" + "=" * 60)
# Out:
# ============================================================
# WORKS CONTENT - Wikisource Availability
# ============================================================
#
# Literary works with Wikisource links (full text available):
#
# Time Period  Total Works  With Wikisource Percentage
#    Before 0          234              104      44.4%
#    0 - 1500         5065              638      12.6%
# 1500 - 1800         9160             2973      32.5%
# 1800 - 1900        27109            12627      46.6%
#       TOTAL        41568            16342      39.3%
#
# ============================================================

# %%
# =============================================================================
# EXPORT: Ancient & Medieval Works with Wikisource (Before 0 CE & 0-1500 CE)
# =============================================================================

conn = sqlite3.connect('../output/literary_works.db')

# Get works from before 1500 with their best Wikisource link (English preferred)
query_ancient_works = """
WITH works_before_1500 AS (
    SELECT DISTINCT
        lw.item_id,
        lw.itemLabel,
        lw.authorLabel,
        lw.instanceLabel,
        MIN(lw.year) as year,
        lw.sitelink_count,
        c.macro_region,
        c.region
    FROM literary_works lw
    LEFT JOIN countries c ON lw.modern_country = c.modern_country
    LEFT JOIN instances i ON lw.instanceLabel = i.label
    WHERE lw.year IS NOT NULL 
      AND lw.year < 1500
      AND c.macro_region IS NOT NULL
      AND (i.excluded = 0 OR i.excluded IS NULL)
    GROUP BY lw.item_id
),
wikisource_ranked AS (
    SELECT 
        item_id,
        sitelink as wikisource_url,
        ROW_NUMBER() OVER (
            PARTITION BY item_id 
            ORDER BY 
                CASE WHEN sitelink LIKE '%en.wikisource%' THEN 1 ELSE 2 END,
                sitelink
        ) as rn
    FROM sitelinks
    WHERE sitelink LIKE '%wikisource%'
)
SELECT 
    w.item_id,
    w.itemLabel as title,
    w.authorLabel as author,
    w.instanceLabel as work_type,
    w.year,
    w.sitelink_count,
    w.macro_region,
    w.region,
    ws.wikisource_url
FROM works_before_1500 w
INNER JOIN wikisource_ranked ws ON w.item_id = ws.item_id AND ws.rn = 1
ORDER BY w.year, w.sitelink_count DESC
"""

df_ancient_ws = pd.read_sql(query_ancient_works, conn)
conn.close()

# Add period column
df_ancient_ws['period'] = df_ancient_ws['year'].apply(
    lambda y: 'Before 0 CE' if y < 0 else '0 - 1500 CE'
)

# Add wikidata URL for reference
df_ancient_ws['wikidata_url'] = 'https://www.wikidata.org/wiki/' + df_ancient_ws['item_id']

# Reorder columns
df_ancient_ws = df_ancient_ws[[
    'item_id', 'title', 'author', 'work_type', 'year', 'period',
    'macro_region', 'region', 'sitelink_count', 'wikisource_url', 'wikidata_url'
]]

# Summary statistics
print("=" * 70)
print("ANCIENT & MEDIEVAL WORKS WITH WIKISOURCE (Before 1500 CE)")
print("=" * 70)
print(f"\nTotal works with Wikisource links: {len(df_ancient_ws):,}")
print(f"  - Before 0 CE:  {len(df_ancient_ws[df_ancient_ws['period'] == 'Before 0 CE']):,}")
print(f"  - 0 - 1500 CE:  {len(df_ancient_ws[df_ancient_ws['period'] == '0 - 1500 CE']):,}")
print(f"\nEnglish Wikisource: {df_ancient_ws['wikisource_url'].str.contains('en.wikisource').sum():,}")
print(f"Other languages:    {(~df_ancient_ws['wikisource_url'].str.contains('en.wikisource')).sum():,}")

# Save to CSV
output_path = '../data/ancient_medieval_works_wikisource.csv'
df_ancient_ws.to_csv(output_path, index=False)
print(f"\nSaved to: {output_path}")
print("=" * 70)
# Out:
# ======================================================================
# ANCIENT & MEDIEVAL WORKS WITH WIKISOURCE (Before 1500 CE)
# ======================================================================
#
# Total works with Wikisource links: 742
#   - Before 0 CE:  104
#   - 0 - 1500 CE:  638
#
# English Wikisource: 163
# Other languages:    579
#
# Saved to: ../data/ancient_medieval_works_wikisource.csv
# ======================================================================

# %%
df_ancient_ws
# Out:
#        item_id                                              title  \
# 0        Q8272                                  Epic of Gilgamesh
# 1      Q727413                                            Rigveda
# 2        Q8275                                              Iliad
# 3      Q667285                                     Works and Days
# 4      Q156498                                           Theogony
# ..         ...                                                ...
# 737   Q3792988                   The Triumph of Bacco and Arianna
# 738   Q3827677                                              Laude
# 739  Q25489503                                     Ha-Lichot Olam
# 740  Q19486611  Relación acerca de las antigüedades de los indios
# 741    Q914235                          Hypnerotomachia Poliphili
#
#                  author      work_type  year       period  \
# 0                  None  literary work -2100  Before 0 CE
# 1       various authors     miscellany -1499  Before 0 CE
# 2                 Homer  literary work  -800  Before 0 CE
# 3                Hesiod  literary work  -800  Before 0 CE
# 4                Hesiod  literary work  -700  Before 0 CE
# ..                  ...            ...   ...          ...
# 737  Lorenzo de' Medici  literary work  1490  0 - 1500 CE
# 738    Jacopone da Todi  literary work  1490  0 - 1500 CE
# 739        Josua Levita  literary work  1490  0 - 1500 CE
# 740          Ramon Pané  literary work  1498  0 - 1500 CE
# 741   Francesco Colonna  literary work  1499  0 - 1500 CE
#
#                       macro_region        region  sitelink_count  \
# 0    Middle-East and Africa (MENA)  Arabic World             127
# 1                             Asia  Indian World             108
# 2                   Eastern Europe       Balkans             176
# 3                   Eastern Europe       Balkans              48
# 4                   Eastern Europe       Balkans              69
# ..                             ...           ...             ...
# 737                 Western Europe         Italy               4
# 738                 Western Europe         Italy               3
# 739  Middle-East and Africa (MENA)  Arabic World               2
# 740                 Western Europe         Spain               2
# 741                 Western Europe         Italy              26
#
#                                         wikisource_url  \
# 0     https://en.wikisource.org/wiki/Epic_of_Gilgamesh
# 1           https://en.wikisource.org/wiki/The_Rigveda
# 2             https://en.wikisource.org/wiki/The_Iliad
# 3        https://en.wikisource.org/wiki/Works_and_Days
# 4              https://en.wikisource.org/wiki/Theogony
# ..                                                 ...
# 737  https://it.wikisource.org/wiki/Opera:Canzona_d...
# 738  https://it.wikisource.org/wiki/Opera:Laude_(Ja...
# 739  https://he.wikisource.org/wiki/%D7%94%D7%9C%D7...
# 740  https://es.wikisource.org/wiki/Relaci%C3%B3n_a...
# 741  https://fr.wikisource.org/wiki/Hypnerotomachia...
#
#                                 wikidata_url
# 0        https://www.wikidata.org/wiki/Q8272
# 1      https://www.wikidata.org/wiki/Q727413
# 2        https://www.wikidata.org/wiki/Q8275
# 3      https://www.wikidata.org/wiki/Q667285
# 4      https://www.wikidata.org/wiki/Q156498
# ..                                       ...
# 737   https://www.wikidata.org/wiki/Q3792988
# 738   https://www.wikidata.org/wiki/Q3827677
# 739  https://www.wikidata.org/wiki/Q25489503
# 740  https://www.wikidata.org/wiki/Q19486611
# 741    https://www.wikidata.org/wiki/Q914235
#
# [742 rows x 11 columns]

# %%
# =============================================================================
# Timeline: Works with Wikisource per 100-year period (log scale)
# =============================================================================

conn = sqlite3.connect('../output/literary_works.db')

query_ws_timeline = """
WITH works_with_year AS (
    SELECT 
        lw.item_id,
        MIN(lw.year) as year
    FROM literary_works lw
    LEFT JOIN countries c ON lw.modern_country = c.modern_country
    LEFT JOIN instances i ON lw.instanceLabel = i.label
    WHERE lw.year IS NOT NULL 
      AND lw.year < 1800
      AND c.macro_region IS NOT NULL
      AND (i.excluded = 0 OR i.excluded IS NULL)
    GROUP BY lw.item_id
),
wikisource_items AS (
    SELECT DISTINCT item_id
    FROM sitelinks
    WHERE sitelink LIKE '%wikisource%'
)
SELECT 
    w.item_id,
    w.year
FROM works_with_year w
INNER JOIN wikisource_items ws ON w.item_id = ws.item_id
"""

df_ws_timeline = pd.read_sql(query_ws_timeline, conn)
conn.close()

# Group by century
df_ws_timeline['century'] = (df_ws_timeline['year'] // 100) * 100
counts_ws_100y = df_ws_timeline.groupby('century')['item_id'].nunique()

fig, ax = plt.subplots(figsize=(14, 6))
ax.bar(counts_ws_100y.index, counts_ws_100y.values, width=80, color='#2E86AB', edgecolor='white')
ax.set_xlabel('Year')
ax.set_ylabel('Number of Works (log scale)')
ax.set_title('Literary Works with Wikisource Links per 100-Year Period', fontsize=14, fontweight='bold')
ax.set_yscale('log')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: format(int(x), ',')))

min_year = (counts_ws_100y.index.min() // 100) * 100
max_year = (counts_ws_100y.index.max() // 100 + 1) * 100
ax.set_xticks(range(min_year, max_year + 1, 200))
ax.set_xticklabels([str(y) for y in range(min_year, max_year + 1, 200)], rotation=45, ha='right')

# Add total count annotation
total_ws = len(df_ws_timeline)
ax.text(0.98, 0.95, f'Total: {total_ws:,} works', transform=ax.transAxes, 
        ha='right', va='top', fontsize=11, fontweight='bold',
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.tight_layout()
plt.show()

# %%
df_ws_timeline.item_id.nunique()
# Out:
# 16342

# %%
df_ancient_ws.item_id.nunique()
# Out:
# 742

# %%
# Preview the dataset - top works by sitelinks (most notable)
df_ancient_ws.sort_values('sitelink_count', ascending=False).head(20)
# Out:
#      item_id                              title              author  \
# 242     Q428                             Qur’an                None
# 2      Q8275                              Iliad               Homer
# 0      Q8272                  Epic of Gilgamesh                None
# 328    Q8279                          Shahnameh   Abu-Mansur Daqiqi
# 71    Q60220                             Aeneid              Virgil
# 347    Q8269                  The Tale of Genji    Murasaki Shikibu
# 1    Q727413                            Rigveda     various authors
# 32   Q123397                       The Republic               Plato
# 104  Q184742                      Metamorphoses                Ovid
# 606   Q16438                      The Decameron  Giovanni Boccaccio
# 402  Q185427                 The Song of Roland              Turold
# 631  Q191663               The Canterbury Tales    Geoffrey Chaucer
# 14   Q241077                           Antigone           Sophocles
# 603   Q70806  The Romance of the Three Kingdoms       Luo Guanzhong
# 56   Q161985                        1 Maccabees                None
# 4    Q156498                           Theogony              Hesiod
# 54   Q233780                       Panchatantra       Vishnu Sharma
# 403  Q131554                     Nibelungenlied                None
# 272  Q813031                             Kojiki        Hieda no Are
# 10   Q276015                           Analects           anonymous
#
#          work_type  year       period                   macro_region  \
# 242  literary work   631  0 - 1500 CE  Middle-East and Africa (MENA)
# 2    literary work  -800  Before 0 CE                 Eastern Europe
# 0    literary work -2100  Before 0 CE  Middle-East and Africa (MENA)
# 328  literary work  1000  0 - 1500 CE  Middle-East and Africa (MENA)
# 71   literary work   -50  Before 0 CE                 Western Europe
# 347  literary work  1010  0 - 1500 CE                           Asia
# 1       miscellany -1499  Before 0 CE                           Asia
# 32   literary work  -379  Before 0 CE                 Eastern Europe
# 104  literary work     1  0 - 1500 CE                 Western Europe
# 606  literary work  1351  0 - 1500 CE                 Western Europe
# 402  literary work  1200  0 - 1500 CE                 Western Europe
# 631  literary work  1387  0 - 1500 CE                 Western Europe
# 14   dramatic work  -441  Before 0 CE                 Eastern Europe
# 603  literary work  1350  0 - 1500 CE                           Asia
# 56   literary work  -200  Before 0 CE  Middle-East and Africa (MENA)
# 4    literary work  -700  Before 0 CE                 Eastern Europe
# 54   literary work  -299  Before 0 CE                           Asia
# 403  literary work  1200  0 - 1500 CE                 Western Europe
# 272  literary work   712  0 - 1500 CE                           Asia
# 10   literary work  -480  Before 0 CE                           Asia
#
#               region  sitelink_count  \
# 242     Arabic World             280
# 2            Balkans             176
# 0       Arabic World             127
# 328    Persian World             126
# 71             Italy             112
# 347            Japan             111
# 1       Indian World             108
# 32           Balkans             100
# 104            Italy              75
# 606            Italy              75
# 402           France              73
# 631  British Islands              70
# 14           Balkans              69
# 603    Chinese World              69
# 56      Arabic World              69
# 4            Balkans              69
# 54      Indian World              67
# 403     German World              65
# 272            Japan              64
# 10     Chinese World              64
#
#                                         wikisource_url  \
# 242            https://en.wikisource.org/wiki/Qur%27an
# 2             https://en.wikisource.org/wiki/The_Iliad
# 0     https://en.wikisource.org/wiki/Epic_of_Gilgamesh
# 328          https://en.wikisource.org/wiki/Shah_Nameh
# 71               https://en.wikisource.org/wiki/Aeneid
# 347   https://en.wikisource.org/wiki/The_Tale_of_Genji
# 1           https://en.wikisource.org/wiki/The_Rigveda
# 32         https://en.wikisource.org/wiki/The_Republic
# 104       https://en.wikisource.org/wiki/Metamorphoses
# 606       https://en.wikisource.org/wiki/The_Decameron
# 402  https://fr.wikisource.org/wiki/La_Chanson_de_R...
# 631  https://en.wikisource.org/wiki/The_Canterbury_...
# 14   https://en.wikisource.org/wiki/Antigone_(Sopho...
# 603  https://en.wikisource.org/wiki/Romance_of_the_...
# 56          https://en.wikisource.org/wiki/1_Maccabees
# 4              https://en.wikisource.org/wiki/Theogony
# 54         https://en.wikisource.org/wiki/Panchatantra
# 403      https://en.wikisource.org/wiki/Nibelungenlied
# 272              https://en.wikisource.org/wiki/Kojiki
# 10             https://en.wikisource.org/wiki/Analects
#
#                               wikidata_url
# 242     https://www.wikidata.org/wiki/Q428
# 2      https://www.wikidata.org/wiki/Q8275
# 0      https://www.wikidata.org/wiki/Q8272
# 328    https://www.wikidata.org/wiki/Q8279
# 71    https://www.wikidata.org/wiki/Q60220
# 347    https://www.wikidata.org/wiki/Q8269
# 1    https://www.wikidata.org/wiki/Q727413
# 32   https://www.wikidata.org/wiki/Q123397
# 104  https://www.wikidata.org/wiki/Q184742
# 606   https://www.wikidata.org/wiki/Q16438
# 402  https://www.wikidata.org/wiki/Q185427
# 631  https://www.wikidata.org/wiki/Q191663
# 14   https://www.wikidata.org/wiki/Q241077
# 603   https://www.wikidata.org/wiki/Q70806
# 56   https://www.wikidata.org/wiki/Q161985
# 4    https://www.wikidata.org/wiki/Q156498
# 54   https://www.wikidata.org/wiki/Q233780
# 403  https://www.wikidata.org/wiki/Q131554
# 272  https://www.wikidata.org/wiki/Q813031
# 10   https://www.wikidata.org/wiki/Q276015
