# %%
import pandas as pd

data = pd.read_csv('written_works_sitelinks.csv')
data = data.dropna()
data = data[data['sitelink'].str.contains('wikisource')]
data = data[['item', 'itemLabel', 'sitelink']].drop_duplicates()
len(set(data.item))
# Out:
# 374

# %%
data[data['item'].str.contains('Q1259616')]
# Out:
# Empty DataFrame
# Columns: [item, itemLabel, date, sitelink]
# Index: []
